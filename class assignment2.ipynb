# %%
from MultipleFunctions import multipleFunctions

# %%
multipleFunctions.SubFields()
# Out:
# Manchine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multipleFunctions.oddEven()
# Out:
# Enter the Number 25
# odd number

# %%
from MultipleFunctions import CalculatePercentage

# %%
CalculatePercentage.FindPercentage()
# Out:
# Subject 1: 98
# Subject 2: 87
# Subject 3: 95
# Subject 4: 95
# Subject 5: 93
# Total 468
# Percentage 93.6
# 'Percentage'

# %%
from MultipleFunctions import AreaandPerimeterofTriangle

# %%
 AreaandPerimeterofTriangle.Triangle1()
# Out:
# Area of the triangle is: 544.0
# perimeter of the triangle is: 98

# %%
from MultipleFunctions import FindTriangle2

# %%
FindTriangle2.Triangle2()
# Out:
# Perimeter of the Triangle is: 10
# 'Perimeter of the Triangle'
