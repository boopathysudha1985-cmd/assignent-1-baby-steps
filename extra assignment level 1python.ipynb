# %%
print("Hope AI")
# Out:
# Hope AI

# %%
print("Enter your Institute name;Hope AI")
# Out:
# Enter your Institute name;Hope AI

# %%
input("Enter Your Name:")
input("Enter your Age:")
input ("Enter your father'sname:")
input("Enter your degree:")
# Out:
# Enter Your Name: Guru
# Enter your Age: 15
# Enter your father'sname: Raman
# Enter your degree: BA
# 'BA'

# %%
num1=int(input("enter tne num1:,"))
num2=int(input("enter the num2:,"))
add=int(num1)+int(num2)
print("addition is:",add)
# Out:
# enter tne num1:, 10
# enter the num2:, 20
# addition is: 30

# %%
a=int(input("enter the num1:,"))
b=int(input("enter the num2:,"))
sub=int(a)-int(b)
print("subtraction :",sub)
# Out:
# enter the num1:, 40
# enter the num2:, 20
# subtraction : 20

# %%
c=int(input("enter the num1:,"))
d=int(input("enter the num2:,"))
mul=int(c)*int(d)
print("multiplication :",mul)
# Out:
# enter the num1:, 66
# enter the num2:, 20
# multiplication : 1320

# %%
x=int(input("enter the num1:,"))
y=int(input("enter the num2:,"))
k=int(x)//int(y)
print("floor division :",k)
# Out:
# enter the num1:, 20
# enter the num2:, 3
# floor division : 6

# %%
n=int(input("enter the num1:,"))
v=int(input("enter the num2:,"))
mod=int(n)%int(v)
print("modulo :",mod)
# Out:
# enter the num1:, 25
# enter the num2:, 3
# modulo : 1
